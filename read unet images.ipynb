# %%
import numpy as np
from os.path import join

# %%
DATA_DIR = '/mnt/pccfs/not_backed_up/sean/data/SIPaKMeD'

# %%
f = join(DATA_DIR, 'Features_CELL/SUP_INT_NUCLEI_FEAT.dat')
with open(join(DATA_DIR, 'Features_CELL/SUP_INT_NUCLEI_FEAT.dat')) as f:
    print(f.readlines())
# Out:
# ['1,1,550,29.19,24.21,0.55868,-85.166,26.463,0.96154,0.73333,75.422,17.411,0.0046401,0.026933,0.028661,5.6421,65.549,7.3838,0.00083775,-6.9021e-05,0.043689,4.6674,38.569,7.3352,0.00082677,0.0096847,0.07559,4.2868\n', '1,2,1175,41.751,35.914,0.50996,-43.077,38.679,0.98326,0.77252,107.86,8.9175,0.0012214,0.010094,0.040313,4.901,81.283,6.5131,0.00065195,0.0025052,0.045403,4.6351,69.012,7.4027,0.00084204,0.0092216,0.052029,4.6098\n', '1,3,2033,54.907,47.346,0.50641,-83.256,50.877,0.97693,0.77008,103.87,11.465,0.0020173,0.012361,0.02658,5.4313,83.195,9.438,0.001368,0.009474,0.032751,5.1487,59.811,10.288,0.001625,0.021768,0.036164,5.1529\n', '1,4,707,32.806,27.637,0.53881,-56.974,30.003,0.98058,0.73646,78.055,16.834,0.0043392,0.038207,0.023865,5.6606,66.737,9.6592,0.0014328,0.0076459,0.032208,5.1375,43.67,10.674,0.0017492,0.031394,0.058664,4.7145\n', '1,5,1757,53.307,42.244,0.6099,24.626,47.298,0.98102,0.78578,74.046,6.2148,0.00059362,0.0015476,0.046954,4.5685,90.553,5.1979,0.00041533,0.00
# ...

# %%
np.fromstring(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8bad8d5d1814> in <module>
# ----> 1 np.fromstring(f)
#
# TypeError: a bytes-like object is required, not '_io.TextIOWrapper'
